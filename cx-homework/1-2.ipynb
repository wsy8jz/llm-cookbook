# %%
import os
from openai import OpenAI

# %%
client = OpenAI(
  api_key="sk-bf1a17bd431e437cbe94f33f58ada359",
  base_url="https://api.deepseek.com"
)
deployment = "deepseek-chat" 
print(client.api_key)
# Out:
# sk-bf1a17bd431e437cbe94f33f58ada359

# %%
def get_completion(prompt, max_tokens=250):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=deployment,
        messages=messages,
        temperature=0.7,
        max_tokens=max_tokens
    )
    content = response.choices[0].message.content
    token_usage = response.usage.total_tokens
    return content, token_usage

# %%
prompt = "写一篇短文，主题是介绍杭州电子科技大学信息工程学院。"
story, token_usage = get_completion(prompt, max_tokens=250)
print("生成的短文:")
print(story)
print("\n使用的Token数量:", token_usage)
# Out:
# 生成的短文:
# ## 杭州电子科技大学信息工程学院：数字时代的筑梦摇篮
#
# 在风景秀丽的杭州，坐落着一所充满活力与创新的高等学府——杭州电子科技大学信息工程学院。作为杭州电子科技大学的重要组成部分，信息工程学院秉承着“笃学力行，守正求新”的校训，致力于培养具备扎实专业知识、创新精神和实践能力的优秀人才，为数字时代的蓬勃发展贡献力量。
#
# **学科优势，筑牢发展根基**
#
# 信息工程学院学科门类齐全，涵盖了计算机科学与技术、软件工程、电子信息工程、通信工程、自动化等多个热门领域。学院拥有一支实力雄厚的师资队伍，其中包括多名国家级和省级教学名师、科研骨干，他们不仅在学术研究上硕果累累，更将丰富的实践经验融入教学，为学生提供最前沿的知识和技能。
#
# **科研平台，激发创新活力**
#
# 学院高度重视科研工作，建有多个国家级和省级重点实验室、工程研究中心，为师生提供了良好的科研平台。近年来，学院承担了多项国家级和省部级科研项目，取得了一系列具有国际影响力的科研成果，为国家和地方经济社会发展做出了重要贡献。
#
#
# 使用的Token数量: 268

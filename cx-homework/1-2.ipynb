# %%
import os
from openai import OpenAI

# %%
client = OpenAI(
  api_key="sk-",
  base_url="https://api.deepseek.com"
)
deployment = "deepseek-chat" 
print(client.api_key)
# Out:
# sk-

# %%
def get_completion(prompt):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=deployment,
        messages=messages,
        temperature=0.7,
        max_tokens=256
    )
    content = response.choices[0].message.content
    token_usage = response.usage.total_tokens
    return content, token_usage

# %%
prompt = "写一篇短文，主题是介绍如何养生。"
story, token_usage = get_completion(prompt)
print("生成的短文:")
print(story)
print("\n使用的Token数量:", token_usage)
# Out:
# 生成的短文:
# ## 养生之道，贵在平衡
#
# 养生，并非追求极致的完美，而是寻求身心的平衡。它如同细水长流，润物无声，在日常点滴中滋养生命。
#
# **饮食有节，滋养脏腑。** 五谷为养，五果为助，五畜为益，五菜为充。饮食应顺应四时，春生夏长，秋收冬藏，选择当季食材，方能滋养五脏六腑。同时，避免暴饮暴食，少食辛辣油腻，以清淡为主，方能保持脾胃健康，运化水谷精微，滋养全身。
#
# **起居有常，顺应自然。** 日出而作，日落而息，顺应自然规律，方能养精蓄锐。夜晚是身体修复的最佳时机，应保证充足的睡眠，让身体得到充分的休息。同时，也要根据自身情况，选择合适的运动方式，如太极拳、八段锦等，舒展筋骨，调和气血，增强体质。
#
# **心境平和，恬淡虚无。** 现代社会节奏快，压力大，保持平和的心态尤为重要。遇事不急不躁，学会调节情绪，以乐观积极
#
# 使用的Token数量: 270
